# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials
import config
import pandas as pd
scope = "user-library-read"

# %%
sp_oauth = SpotifyOAuth( client_id    =config.SPOTIPY_CLIENT_ID,
                    client_secret=config.SPOTIPY_CLIENT_SECRET,
                    redirect_uri =config.SPOTIPY_REDIRECT_URI,
                    scope=scope)

sp = spotipy.Spotify(auth_manager=sp_oauth)

# %%
# Fetch user's saved tracks (max limit by api call is 50)
track_limit = 50
results = sp.current_user_saved_tracks(limit=track_limit)

# %%
results.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
print("href': ", results['href'])
print("total: ", results['total'])
print("limit: ", results['limit'])
print("next': ", results['next'])
print("offset: ", results['offset'])
print("previous: ", results['previous'])
print("total: ", results['total'])
# Out:
# href':  https://api.spotify.com/v1/me/tracks?offset=0&limit=50
# total:  1573
# limit:  50
# next':  https://api.spotify.com/v1/me/tracks?offset=50&limit=50
# offset:  0
# previous:  None
# total:  1573

# %%
print(type(results['items']))
print(len(results['items']))
# Out:
# <class 'list'>
# 50

# %%
results['items'][0]
# Out:
# {'added_at': '2024-07-11T18:26:43Z',
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41X1TR6hrK8Q2ZCpp2EqCz'},
#      'href': 'https://api.spotify.com/v1/artists/41X1TR6hrK8Q2ZCpp2EqCz',
#      'id': '41X1TR6hrK8Q2ZCpp2EqCz',
#      'name': 'bbno$',
#      'type': 'artist',
#      'uri': 'spotify:artist:41X1TR6hrK8Q2ZCpp2EqCz'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6tl4X5mM1eOnkWr7oB5LAM'},
#    'href': 'https://api.spotify.com/v1/albums/6tl4X5mM1eOnkWr7oB5LAM',
#    'id': '6tl4X5mM1eOnkWr7oB5LAM',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273eb98fd1d2c60d532584f1b52',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02eb98fd1d2c60d532584f1b52',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851eb98fd1d2c60d532584f1b52',
#      'width': 64}],
#    'name': 'it boy',
#    'release_date': '2024-05-24',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:6tl4X5mM1eOnkWr7oB5LAM'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41X1TR6hrK8Q2ZCpp2EqCz'},
#     'href': 'https://api.spotify.com/v1/artists/41X1TR6hrK8Q2ZCpp2EqCz',
#     'id': '41X1TR6hrK8Q2ZCpp2EqCz',
#     'name': 'bbno$',
#     'type': 'artist',
#     'uri': 'spotify:artist:41X1TR6hrK8Q2ZCpp2EqCz'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 145846,
#   'explicit': True,
#   'external_ids': {'isrc': 'QM24S2402801'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2UerDbZznc07mmGMD3WfHH'},
#   'href': 'https://api.spotify.com/v1/tracks/2UerDbZznc07mmGMD3WfHH',
#   'id': '2UerDbZznc07mmGMD3WfHH',
#   'is_local': False,
#   'name': 'it boy',
#   'popularity': 77,
#   'preview_url': 'https://p.scdn.co/mp3-preview/2de14d81fabd08af4e3014ea936158bae28b7849?cid=11b7e95b31264fec8da565e9823abe72',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:2UerDbZznc07mmGMD3WfHH'}}

# %%
results['items'][0].keys()
# Out:
# dict_keys(['added_at', 'track'])

# %%
results['items'][0]['track']
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41X1TR6hrK8Q2ZCpp2EqCz'},
#     'href': 'https://api.spotify.com/v1/artists/41X1TR6hrK8Q2ZCpp2EqCz',
#     'id': '41X1TR6hrK8Q2ZCpp2EqCz',
#     'name': 'bbno$',
#     'type': 'artist',
#     'uri': 'spotify:artist:41X1TR6hrK8Q2ZCpp2EqCz'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6tl4X5mM1eOnkWr7oB5LAM'},
#   'href': 'https://api.spotify.com/v1/albums/6tl4X5mM1eOnkWr7oB5LAM',
#   'id': '6tl4X5mM1eOnkWr7oB5LAM',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273eb98fd1d2c60d532584f1b52',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02eb98fd1d2c60d532584f1b52',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851eb98fd1d2c60d532584f1b52',
#     'width': 64}],
#   'name': 'it boy',
#   'release_date': '2024-05-24',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:6tl4X5mM1eOnkWr7oB5LAM'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41X1TR6hrK8Q2ZCpp2EqCz'},
#    'href': 'https://api.spotify.com/v1/artists/41X1TR6hrK8Q2ZCpp2EqCz',
#    'id': '41X1TR6hrK8Q2ZCpp2EqCz',
#    'name': 'bbno$',
#    'type': 'artist',
#    'uri': 'spotify:artist:41X1TR6hrK8Q2ZCpp2EqCz'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'PR',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 145846,
#  'explicit': True,
#  'external_ids': {'isrc': 'QM24S2402801'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/2UerDbZznc07mmGMD3WfHH'},
#  'href': 'https://api.spotify.com/v1/tracks/2UerDbZznc07mmGMD3WfHH',
#  'id': '2UerDbZznc07mmGMD3WfHH',
#  'is_local': False,
#  'name': 'it boy',
#  'popularity': 77,
#  'preview_url': 'https://p.scdn.co/mp3-preview/2de14d81fabd08af4e3014ea936158bae28b7849?cid=11b7e95b31264fec8da565e9823abe72',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:2UerDbZznc07mmGMD3WfHH'}

# %%
results['items'][0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
print("album:", results['items'][0]['track']['album'])
print("artists:", results['items'][0]['track']['artists'])
print("duration:", results['items'][0]['track']['duration_ms'])
print("explicit:", results['items'][0]['track']['explicit'])
print("name:", results['items'][0]['track']['name'])
print("popularity:", results['items'][0]['track']['popularity'])
print("type:", results['items'][0]['track']['type'])
# Out:
# album: {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41X1TR6hrK8Q2ZCpp2EqCz'}, 'href': 'https://api.spotify.com/v1/artists/41X1TR6hrK8Q2ZCpp2EqCz', 'id': '41X1TR6hrK8Q2ZCpp2EqCz', 'name': 'bbno$', 'type': 'artist', 'uri': 'spotify:artist:41X1TR6hrK8Q2ZCpp2EqCz'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'PR', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/6tl4X5mM1eOnkWr7oB5LAM'}, 'href': 'https://api.spotify.com/v1/albums/6tl4X5mM1eOnkWr7oB5LAM', 'id': '6tl4X5mM1eOnkWr7oB5LAM', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273eb98fd1d2c60d532584f1b52', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02eb98fd1d2c60d532584f1b52', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851eb98fd1d2c60d532584f1b52', 'width': 64}], 'name': 'it boy', 'release_date': '2024-05-24', 'release_date_precision': 'day', 'total_tracks': 1, 'type': 'album', 'uri': 'spotify:album:6tl4X5mM1eOnkWr7oB5LAM'}
# artists: [{'external_urls': {'spotify': 'https://open.spotify.com/artist/41X1TR6hrK8Q2ZCpp2EqCz'}, 'href': 'https://api.spotify.com/v1/artists/41X1TR6hrK8Q2ZCpp2EqCz', 'id': '41X1TR6hrK8Q2ZCpp2EqCz', 'name': 'bbno$', 'type': 'artist', 'uri': 'spotify:artist:41X1TR6hrK8Q2ZCpp2EqCz'}]
# duration: 145846
# explicit: True
# name: it boy
# popularity: 77
# type: track

# %%
track_id = ['41X1TR6hrK8Q2ZCpp2EqCz']
features = sp.audio_features(track_id)[0]
# Out:
# Max Retries reached
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# ResponseError: too many 429 error responses
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:934, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     933 try:
# --> 934     retries = retries.increment(method, url, response=response, _pool=self)
#     935 except MaxRetryError:
#
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=41X1TR6hrK8Q2ZCpp2EqCz (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\spotipy\client.py:270, in Spotify._internal_call(self, method, url, payload, params)
#     269 try:
# --> 270     response = self._session.request(
#     271         method, url, headers=headers, proxies=self.proxies,
#     272         timeout=self.requests_timeout, **args
#     273     )
#     275     response.raise_for_status()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\adapters.py:691, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     690 if isinstance(e.reason, ResponseError):
# --> 691     raise RetryError(e, request=request)
#     693 if isinstance(e.reason, _ProxyError):
#
# RetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=41X1TR6hrK8Q2ZCpp2EqCz (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[92], line 2
#       1 track_id = ['41X1TR6hrK8Q2ZCpp2EqCz']
# ----> 2 features = sp.audio_features(track_id)[0]['valence']
#
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\spotipy\client.py:1753, in Spotify.audio_features(self, tracks)
#    1751 else:
#    1752     tlist = [self._get_id("track", t) for t in tracks]
# -> 1753     results = self._get("audio-features/?ids=" + ",".join(tlist))
#    1754 # the response has changed, look for the new style first, and if
#    1755 # it's not there, fallback on the old style
#    1756 if "audio_features" in results:
#
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\spotipy\client.py:327, in Spotify._get(self, url, args, payload, **kwargs)
#     324 if args:
#     325     kwargs.update(args)
# --> 327 return self._internal_call("GET", url, payload, kwargs)
#
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\spotipy\client.py:311, in Spotify._internal_call(self, method, url, payload, params)
#     309     except (IndexError, AttributeError):
#     310         reason = None
# --> 311     raise SpotifyException(
#     312         429,
#     313         -1,
#     314         f"{request.path_url}:\n Max Retries",
#     315         reason=reason
#     316     )
#     317 except ValueError:
#     318     results = None
#
# SpotifyException: http status: 429, code:-1 - /v1/audio-features/?ids=41X1TR6hrK8Q2ZCpp2EqCz:
#  Max Retries, reason: too many 429 error responses

# %%
# Create a list to store track information
tracks_data = []
def get_track_data(track):
    track_id = track['id']
    features = sp.audio_features(track_id)[0]

    # Combine track info and features into a single dictionary
    track_info = {
        'name': track['name'],
        'album': track['album']['name'],
        'artist': track['artists'][0]['name'],
        'release_date': track['album']['release_date'],
        'length': track['duration_ms'],
        'popularity': track['popularity'],
        'acousticness': features['acousticness'],
        'danceability': features['danceability'],
        'energy': features['energy'],
        'instrumentalness': features['instrumentalness'],
        'liveness': features['liveness'],
        'loudness': features['loudness'],
        'speechiness': features['speechiness'],
        'tempo': features['tempo'],
        'time_signature': features['time_signature']
    }
    return track_info


# Extract desired information
while results['next']:
    for item in results['items']:
        track_info = get_track_data(results['items'][0]['track'])
        tracks_data.append(track_info)
    results = sp.next(results)
# Out:
# Max Retries reached
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# ResponseError: too many 429 error responses
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:944, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     943     log.debug("Retry: %s", url)
# --> 944     return self.urlopen(
#     945         method,
#     946         url,
#     947         body,
#     948         headers,
#     949         retries=retries,
#     950         redirect=redirect,
#     951         assert_same_host=assert_same_host,
#     952         timeout=timeout,
#     953         pool_timeout=pool_timeout,
#     954         release_conn=release_conn,
#     955         chunked=chunked,
#     956         body_pos=body_pos,
#     957         preload_content=preload_content,
#     958         decode_content=decode_content,
#     959         **response_kw,
#     960     )
#     962 return response
#
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:934, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     933 try:
# --> 934     retries = retries.increment(method, url, response=response, _pool=self)
#     935 except MaxRetryError:
#
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=2UerDbZznc07mmGMD3WfHH (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# RetryError                                Traceback (most recent call last)
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\spotipy\client.py:270, in Spotify._internal_call(self, method, url, payload, params)
#     269 try:
# --> 270     response = self._session.request(
#     271         method, url, headers=headers, proxies=self.proxies,
#     272         timeout=self.requests_timeout, **args
#     273     )
#     275     response.raise_for_status()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\requests\adapters.py:691, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     690 if isinstance(e.reason, ResponseError):
# --> 691     raise RetryError(e, request=request)
#     693 if isinstance(e.reason, _ProxyError):
#
# RetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=2UerDbZznc07mmGMD3WfHH (Caused by ResponseError('too many 429 error responses'))
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[94], line 31
#      29 while results['next']:
#      30     for item in results['items']:
# ---> 31         track_info = get_track_data(results['items'][0]['track'])
#      32         tracks_data.append(track_info)
#      33     results = sp.next(results)
#
# Cell In[94], line 5, in get_track_data(track)
#       3 def get_track_data(track):
#       4     track_id = track['id']
# ----> 5     features = sp.audio_features(track_id)[0]
#       7     # Combine track info and features into a single dictionary
#       8     track_info = {
#       9         'name': track['name'],
#      10         'album': track['album']['name'],
#    (...)
#      23         'time_signature': features['time_signature']
#      24     }
#
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\spotipy\client.py:1750, in Spotify.audio_features(self, tracks)
#    1748 if isinstance(tracks, str):
#    1749     trackid = self._get_id("track", tracks)
# -> 1750     results = self._get("audio-features/?ids=" + trackid)
#    1751 else:
#    1752     tlist = [self._get_id("track", t) for t in tracks]
#
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\spotipy\client.py:327, in Spotify._get(self, url, args, payload, **kwargs)
#     324 if args:
#     325     kwargs.update(args)
# --> 327 return self._internal_call("GET", url, payload, kwargs)
#
# File c:\Users\alexc\AppData\Local\Programs\Python\Python312\Lib\site-packages\spotipy\client.py:311, in Spotify._internal_call(self, method, url, payload, params)
#     309     except (IndexError, AttributeError):
#     310         reason = None
# --> 311     raise SpotifyException(
#     312         429,
#     313         -1,
#     314         f"{request.path_url}:\n Max Retries",
#     315         reason=reason
#     316     )
#     317 except ValueError:
#     318     results = None
#
# SpotifyException: http status: 429, code:-1 - /v1/audio-features/?ids=2UerDbZznc07mmGMD3WfHH:
#  Max Retries, reason: too many 429 error responses

# %%
df = pd.DataFrame(tracks_data)
df
# Out:
#                                                  name  \
# 0   Infinity Repeating (2013 Demo) [feat. Julian C...
# 1                                    Going Gets Tough
# 2                                        Mystery Girl
# 3                                         Italo Disco
# 4                                                Zoom
# 5                                              Medusa
# 6                                         Best Friend
# 7                        Keeping Tabs (feat. Suscat0)
# 8                                     Winter's Ballad
# 9                                 Just the Right Song
# 10                              From the Subway Train
# 11                                            Friends
# 12                                         Telephones
# 13                                              Young
# 14                                               Home
# 15                           Sowing The Seeds Of Love
# 16                                            Weather
# 17                                         Le château
# 18                                          Mad World
# 19                                            Frutsi!
# 20                                           Telefono
# 21                                         Via Veneto
# 22                                         Role Model
# 23                                      Fior Di Latte
# 24                                        Tuttifrutti
# 25                                             Ti Amo
# 26                                              J-Boy
# 27                                  Trying to Be Cool
# 28                                      Entertainment
# 29                                         Girlfriend
# 30                                          Too Young
# 31                                              Lasso
# 32                      After Midnight (feat. Clairo)
# 33                                               1901
# 34                                          Buttercup
# 35                                        Way It Goes
# 36                                         Good Grief
# 37                                      Bad Decisions
# 38                                        Don't Speak
# 39                                        Just A Girl
# 40                                  Meet Me in Mexico
# 41                                       When You Die
# 42                                   Level of Concern
# 43                                Cigarette Daydreams
# 44                                  ANGRY BIRDS PHONK
# 45                                           Crystals
# 46                                    METAMORPHOSIS 3
# 47                                           One Beer
# 48                                           All Caps
# 49                                           Doomsday
#
#                                                 album             artist  \
# 0   Infinity Repeating (2013 Demo) [feat. Julian C...          Daft Punk
# 1                                    Chinese Fountain       The Growlers
# 2                                        Mystery Girl          Housecall
# 3                                       Yumeno Garden     Last Dinosaurs
# 4                                  In A Million Years     Last Dinosaurs
# 5                                              Medusa           Caloncho
# 6                                             Para Mi               Cuco
# 7                                             Para Mi               Cuco
# 8                                             Songs4u               Cuco
# 9                            The Modern Western World            Vansire
# 10                                        Angel Youth            Vansire
# 11                                              Vibes          Vacations
# 12                                            Changes          Vacations
# 13                                              Vibes          Vacations
# 14                                              Vibes          Vacations
# 15                                  The Seeds Of Love    Tears For Fears
# 16                                            Weather        Ginger Root
# 17                                              Rikki        Ginger Root
# 18                                        The Hurting    Tears For Fears
# 19                                            Frutsi!    Gabriela Triste
# 20                                             Ti Amo            Phoenix
# 21                                             Ti Amo            Phoenix
# 22                                             Ti Amo            Phoenix
# 23                                             Ti Amo            Phoenix
# 24                                             Ti Amo            Phoenix
# 25                                             Ti Amo            Phoenix
# 26                                             Ti Amo            Phoenix
# 27                                          Bankrupt!            Phoenix
# 28                                          Bankrupt!            Phoenix
# 29                           Wolfgang Amadeus Phoenix            Phoenix
# 30                                             United            Phoenix
# 31                           Wolfgang Amadeus Phoenix            Phoenix
# 32                      After Midnight (feat. Clairo)            Phoenix
# 33                           Wolfgang Amadeus Phoenix            Phoenix
# 34                                           Landmark       Hippo Campus
# 35                                           Landmark       Hippo Campus
# 36                      Wild World (Complete Edition)           Bastille
# 37                                   The New Abnormal        The Strokes
# 38                                     Tragic Kingdom           No Doubt
# 39                                     Tragic Kingdom           No Doubt
# 40                                  Meet Me in Mexico          The Drums
# 41                                    Little Dark Age               MGMT
# 42                                   Level of Concern  Twenty One Pilots
# 43                                         Melophobia  Cage The Elephant
# 44                                  Angry Birds Phonk            RXDXVIL
# 45                                           Crystals        Isolate.exe
# 46                                    METAMORPHOSIS 3         INTERWORLD
# 47                                          MM...FOOD            MF DOOM
# 48                                        Madvillainy         Madvillain
# 49                     Operation: Doomsday (Complete)            MF DOOM
#
#    release_date  length  popularity
# 0    2023-05-11  239213          47
# 1    2014-09-23  208613          60
# 2    2018-07-11  176536          45
# 3    2018-10-05  226303          52
# 4    2012-01-01  240666          44
# 5    2023-04-12  178026          45
# 6    2019-07-26  150198          48
# 7    2019-07-26  248160          52
# 8    2017-01-28  277122          49
# 9    2022-05-12  186253          51
# 10   2018-04-26   57370          76
# 11         2016  152360          66
# 12         2018  212432          78
# 13         2016  189160          78
# 14         2016  145666          68
# 15   1989-09-25  376733           2
# 16   2019-06-05  222976          45
# 17   2020-10-23  155855          53
# 18   1983-03-07  215400          67
# 19   2020-02-29  185024          32
# 20   2017-06-09  225400           0
# 21   2017-06-09  161853           0
# 22   2017-06-09  275520           0
# 23   2017-06-09  243733           0
# 24   2017-06-09  232680           0
# 25   2017-06-09  205920           0
# 26   2017-06-09  248213           0
# 27   2013-04-19  229560           0
# 28   2013-04-19  220240           0
# 29         2009  204133           0
# 30   2000-03-06  197973          58
# 31         2009  167853           0
# 32   2023-03-16  188000          53
# 33         2009  193120           1
# 34   2017-02-24  226610          59
# 35   2017-02-24  245456          48
# 36   2016-09-09  206493          59
# 37   2020-04-10  293360          59
# 38   1995-10-10  263560          78
# 39   1995-10-10  209200          74
# 40   2018-02-15  228160          33
# 41   2018-02-09  263880          61
# 42   2020-04-09  220051          62
# 43   2013-10-08  208760          80
# 44   2023-01-16   74963          43
# 45   2022-01-28  139200          69
# 46   2023-04-14  128015          62
# 47   2004-11-16  258586          71
# 48   2004-03-24  130479          68
# 49   1999-10-19  298053          71

# %%
# Save the DataFrame to a CSV file
csv_name = 'liked songs data.csv'
df.to_csv(csv_name, index=False)

print(f"Data has been saved to {csv_name}")
# Out:
# Data has been saved to liked songs data.csv
